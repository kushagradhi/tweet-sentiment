# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import re

xls_dir="sample.xlsx"
porter=PorterStemmer()

# %%
columns=[3,4]
df=pd.read_excel(xls_dir, sheet_names='Obama', usecols=columns, header=1, names=['Tweet', 'Sentiment'])
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tweet</th>
#       <th>Sentiment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Kirkpatrick, who wore a baseball cap embroider...</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Question: If &lt;e&gt;Romney&lt;/e&gt; and &lt;e&gt;Obama&lt;/e&gt; ha...</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>#&lt;e&gt;obama&lt;/e&gt; debates that Cracker Ass Cracker...</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>RT @davewiner Slate: Blame &lt;e&gt;Obama&lt;/e&gt; for fo...</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>@Hollivan @hereistheanswer  Youre missing the ...</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>&lt;e&gt;Mitt Romney&lt;/e&gt; made all of his money himse...</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>I was raised as a Democrat  left the party yea...</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>The &lt;e&gt;Obama camp&lt;/e&gt; can't afford to lower ex...</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Tonight's debate has that "Game 7" feel! This ...</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>&lt;e&gt;Obama&lt;/e&gt; pot &lt;a&gt;policy&lt;/a&gt; disappointing -...</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Not all of Hollywood has his back! RT @RedAler...</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>@hblodget i'd be grateful for scoop from you g...</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>&lt;e&gt;Obama&lt;/e&gt; must, to a degree, hit &lt;e&gt;MR&lt;/e&gt; ...</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>&lt;e&gt;Obama&lt;/e&gt;'s Expedient Speak fair in order t...</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>I had a dream that i was smoking with &lt;e&gt;Obama...</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>The Washington Times: The President’s Populari...</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>&lt;e&gt;Obama&lt;/e&gt;'s priorities: $30K for "gaydar" r...</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>United states of Islam ? Does &lt;e&gt;Obama&lt;/e&gt; rea...</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>@FightForJobs :they created this debt now plam...</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>NaN</td>
#       <td>-1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.drop(df[(df.Sentiment==0) | (df.Sentiment==2)].index, inplace=True)
df.dropna(how='any', inplace=True)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tweet</th>
#       <th>Sentiment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>#&lt;e&gt;obama&lt;/e&gt; debates that Cracker Ass Cracker...</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>I was raised as a Democrat  left the party yea...</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>&lt;e&gt;Obama&lt;/e&gt; pot &lt;a&gt;policy&lt;/a&gt; disappointing -...</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Not all of Hollywood has his back! RT @RedAler...</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>The Washington Times: The President’s Populari...</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>&lt;e&gt;Obama&lt;/e&gt;'s priorities: $30K for "gaydar" r...</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>United states of Islam ? Does &lt;e&gt;Obama&lt;/e&gt; rea...</td>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>@FightForJobs :they created this debt now plam...</td>
#       <td>-1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Remove tags
df['Tweet'] = df['Tweet'].apply(lambda x: re.sub("<.*?>", '', x))

#Stemming
def stem(tweet):
    tokens=word_tokenize(tweet)
    result=[]
    for token in tokens:
        result.extend([porter.stem(token), " "])
    return "".join(result)
df['Tweet'] = df['Tweet'].apply(stem)

#remove punctuation


#lowerCase
df['Tweet'] = df['Tweet'].apply(lambda x: ' '.join([word.lower() for word in x.split()]))

#remove stopwords
stopwords_english=stopwords.words("english")
df['Tweet'] = df['Tweet'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords_english)]))
df
